# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib import pyplot as plt
from sklearn.model_selection import cross_val_score
# %matplotlib inline
import os
sns.set(color_codes=True)

# %%
source=pd.read_csv('Z:/datasets/ECG/The_PTB_Diagnostic_ECG_Database/ALL.csv')

# %%
infarct = source[source['diagnose'] == 'Myocardial infarction']
healthy = source[source['diagnose'] == 'Healthy control']
infarct=infarct[0:10]
healthy=healthy[0:10]

# %%
infarcts = []
for r in (infarct['code_record']):
    e=os.path.join('Z:/datasets/ECG/The_PTB_Diagnostic_ECG_Database/', r)
    j=pd.read_csv(e+'.csv')
    j=j.drop('Unnamed: 0', axis=1)
    infarcts.append(j)

# %%
healthys = []
for r in (healthy['code_record']):
    e=os.path.join('Z:/datasets/ECG/The_PTB_Diagnostic_ECG_Database/', r)
    j=pd.read_csv(e+'.csv')
    j=j.drop('Unnamed: 0', axis=1)
    healthys.append(j)

# %%
# Out:
# [            i      ii     iii     avr     avl     avf      v1      v2      v3  \
#  0     -0.2445 -0.2290  0.0155  0.2370 -0.1300 -0.1070 -0.0440 -0.1205 -0.0560
#  1     -0.2425 -0.2335  0.0090  0.2380 -0.1255 -0.1125 -0.0420 -0.1175 -0.0510
#  2     -0.2415 -0.2345  0.0070  0.2380 -0.1240 -0.1140 -0.0440 -0.1180 -0.0535
#  3     -0.2410 -0.2290  0.0120  0.2350 -0.1260 -0.1090 -0.0450 -0.1175 -0.0515
#  4     -0.2315 -0.2270  0.0045  0.2295 -0.1180 -0.1115 -0.0455 -0.1170 -0.0495
#  5     -0.2260 -0.2325 -0.0070  0.2295 -0.1095 -0.1200 -0.0505 -0.1210 -0.0530
#  6     -0.2250 -0.2365 -0.0115  0.2310 -0.1065 -0.1245 -0.0525 -0.1215 -0.0545
#  7     -0.2345 -0.2335  0.0005  0.2340 -0.1170 -0.1170 -0.0490 -0.1175 -0.0505
#  8     -0.2345 -0.2330  0.0015  0.2335 -0.1180 -0.1160 -0.0515 -0.1180 -0.0500
#  9     -0.2235 -0.2355 -0.0120  0.2295 -0.1055 -0.1240 -0.0550 -0.1205 -0.0540
#  10    -0.2205 -0.2305 -0.0105  0.2255 -0.1045 -0.1210 -0.0545 -0.1230 -0.0540
# ...
