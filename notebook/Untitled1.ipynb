# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("source.csv")

# %% [markdown]
# проверяю на Н/А

# %%
df=df.dropna()

# %% [markdown]
# Преобразую образование в читаемый вид

# %%
for number in  range(df.shape[0]):
    df.requirement[number]=df.requirement[number][12:-2]
    print(df.requirement[number])
# Out:
# /home/wsuser/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Среднее
# Среднее профессиональное
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее профессиональное
# Среднее профессиональное
# Высшее
# Среднее
# Высшее
# Высшее
# Среднее профессиональное
# от 1
# Высшее
# None
# Среднее профессиональное
# None
# Высшее
# Высшее
# Высшее
# Высшее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# Среднее
# от 1
# Среднее профессиональное
# Высшее
# Высшее
# Среднее профессиональное
# Высшее
# Высшее
# <p>Условия: работа 6 дней через 2, 8-ми часовой рабочий день, работа на автомобиле Газель (хлебовозка).</p>\nТребуется водительское удостоверение категории B\n
# Высшее
# Среднее профессиональное
# Высшее
# ...

# %%
from datetime import datetime
sec=[]
for number in  range(df.shape[0]):
    x=datetime.strptime( df["update-date"][number][:-4], "%Y-%m-%d %H:%M:%S" )-datetime.strptime( df["creation-date"][number][:-4], "%Y-%m-%d %H:%M:%S")
    print (x.seconds)
    sec.append (x.seconds)
# Out:
# 79111
# 76853
# 79227
# 79252
# 80580
# 80585
# 80591
# 80597
# 80603
# 2118
# 2111
# 11060
# 79284
# 4215
# 5501
# 5509
# 5505
# 7407
# 7489
# 7622
# 7644
# 9505
# 11303
# 11333
# 11339
# 80468
# 80474
# 80481
# 80457
# 80462
# 86009
# 86020
# 86027
# 11742
# 11648
# 11346
# 11351
# 11353
# 11341
# 11338
# 11345
# 11348
# 11344
# 11350
# 79187
# 79312
# 25985
# 25948
# 25987
# 25988
# 25952
# 25963
# 25967
# 25973
# 25975
# 25982
# 26080
# 26120
# 29732
# 30375
# 30691
# 31283
# 31308
# 31288
# 31285
# 31294
# 31550
# 31491
# 31509
# 31860
# 31851
# 31841
# 31860
# 32288
# 32271
# 32291
# 32282
# 32285
# 33307
# 33699
# 33697
# 33693
# 36270
# 36226
# 36214
# 36499
# 36391
# 36507
# 36392
# 37214
# 37221
# 37207
# 37214
# 39769
# 40270
# 40633
# 40640
# 40644
# 40642
# 41011
# 41081
# 41113
# 41112
# 41134
# 41146
# 41154
# 41353
# 41284
# 41270
# 41595
# 41601
# 41698
# 41702
# 41706
# 41676
# 41718
# 41712
# 41714
# 41708
# 41722
# 41726
# 41729
# 41732
# 41736
# 41741
# 41745
# ...

# %%
df=df.drop('category',axis=1)
df=df.drop('Unnamed: 0',axis=1)
df=df.drop('description',axis=1)
df=df.drop('duty',axis=1)
df=df.drop('company',axis=1)
df=df.drop('url',axis=1)

# %%
df
# Out:
#                                                    url  \
# 0    https://trudvsem.ru/vacancy/card/3075743092001...
# 1    https://trudvsem.ru/vacancy/card/3126910133000...
# 2    https://trudvsem.ru/vacancy/card/3075743092001...
# 3    https://trudvsem.ru/vacancy/card/3075743092001...
# 4    https://trudvsem.ru/vacancy/card/3083254220000...
# 5    https://trudvsem.ru/vacancy/card/3083254220000...
# 6    https://trudvsem.ru/vacancy/card/3083254220000...
# 7    https://trudvsem.ru/vacancy/card/3083254220000...
# 8    https://trudvsem.ru/vacancy/card/3083254220000...
# 9    https://trudvsem.ru/vacancy/card/1037739369690...
# 10   https://trudvsem.ru/vacancy/card/1037739369690...
# 11   https://trudvsem.ru/vacancy/card/1081428000081...
# 12   https://trudvsem.ru/vacancy/card/3075743092001...
# 13   https://trudvsem.ru/vacancy/card/1034100957428...
# 14   https://trudvsem.ru/vacancy/card/1137746904030...
# 15   https://trudvsem.ru/vacancy/card/1137746904030...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %% [markdown]
# Имена профессий по иксу и их количество по y
# Ввиду многобразия профессий, график не читаем

# %%
sns.catplot(x="job-name", kind="count", data=df);
# Out:
# /home/wsuser/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '

# %%
sns.set(rc={'figure.figsize':(50,50)})
sns.catplot(x="schedule", kind="count", data=df);

# %%
sns.catplot(x="requirement", kind="count", data=df);
# Out:
# /home/wsuser/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:176: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('Tight layout not applied. The left and right margins '

# %%
sns.catplot(x="employment", kind="count", data=df);
